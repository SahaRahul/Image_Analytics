# %% [markdown]
# <a href="https://colab.research.google.com/github/SahaRahul/Call-For-Code-2020/blob/master/Image_Classification_Using_IBM_Watson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installation of IBM Watson package to python

# %%
# !pip install --upgrade "watson-developer-cloud>=2.4.1"
# Out:
# ...
#      |████████████████████████████████| 256kB 5.0MB/s
# ...
#      |████████████████████████████████| 204kB 12.4MB/s
# ...
#   Created wheel for watson-developer-cloud: filename=watson_developer_cloud-2.10.1-cp36-none-any.whl size=252813 sha256=c2104260ca9d1b00686d096b98c0e10e74805f3969209bc468f456ef0076859c
#   Stored in directory: /root/.cache/pip/wheels/ea/a7/19/fac0a408a586265eb374005308a7553d4494ab41b2fd88f5bc
# Successfully built watson-developer-cloud
# ...

# %% [markdown]
# ## Authentication

# %%
from watson_developer_cloud import VisualRecognitionV3

visual_recognition = VisualRecognitionV3(
    version='{version}',
    iam_apikey='TLAJCzVe0F3jESVgfQhdVINMIxSpWRrMvhdrUBWDRHoA'
)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
#   """

# %% [markdown]
# ## Classify an image of House with Solar Panel

# %%
import json
from watson_developer_cloud import VisualRecognitionV3

visual_recognition = VisualRecognitionV3(
    '2018-03-19',
    iam_apikey='TLAJCzVe0F3jESVgfQhdVINMIxSpWRrMvhdrUBWDRHoA')

with open('./image01.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.6',
	classifier_ids='default').get_result()
print(json.dumps(classes, indent=2))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "solar house",
#               "score": 0.809,
#               "type_hierarchy": "/building/solar house"
#             },
#             {
#               "class": "building",
#               "score": 0.809
#             },
#             {
#               "class": "solar cell",
#               "score": 0.717,
#               "type_hierarchy": "/electrical device/solar cell"
#             },
#             {
#               "class": "electrical device",
#               "score": 0.922
#             },
#             {
#               "class": "solar array",
#               "score": 0.715,
# ...

# %%
# !pip install pillow

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

#read the image
im = Image.open("image01.jpg")

#show image
plt.imshow(im)

# %%
import cv2

# %%
image = cv2.imread('image01.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# ## Classify an House without Solar Panel

# %%
with open('./image01_N.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.6',
        classifier_ids='default').get_result()
print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "gambrel roof",
#               "score": 0.798,
#               "type_hierarchy": "/protective covering/gambrel roof"
#             },
#             {
#               "class": "protective covering",
#               "score": 0.798
#             },
#             {
#               "class": "sage green color",
#               "score": 0.932
#             }
#           ]
#         }
#       ],
#       "image": "image01_N.jpg"
#     }
#   ],
#   "images_processed": 1,
#   "custom_classes": 0
# }

# %%
#read the image
im = Image.open("image01_N.jpg")

#show image
plt.imshow(im)

# %%
with open('./waterImage01.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.6',
        classifier_ids='default').get_result()
print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "Fishpond",
#               "score": 0.85
#             },
#             {
#               "class": "nature",
#               "score": 0.784
#             },
#             {
#               "class": "jade green color",
#               "score": 0.843
#             },
#             {
#               "class": "greenishness color",
#               "score": 0.796
#             }
#           ]
#         }
#       ],
#       "image": "waterImage01.jpg"
#     }
#   ],
#   "images_processed": 1,
#   "custom_classes": 0
# }

# %%
#read the image
im = Image.open("waterImage01.jpg")

#show image
plt.imshow(im)

# %%
with open('./waterImage02.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.5',
        classifier_ids='default').get_result()
print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "person",
#               "score": 0.678
#             },
#             {
#               "class": "Fishpond",
#               "score": 0.524
#             },
#             {
#               "class": "riverbank",
#               "score": 0.5,
#               "type_hierarchy": "/nature/slope/riverbank"
#             },
#             {
#               "class": "slope",
#               "score": 0.502
#             },
#             {
#               "class": "nature",
#               "score": 0.503
#             },
#             {
#               "class": "tree",
#               "score": 0.599
#             },
#             {
#               "class": "greenishness color",
#               "score": 0.892
#             },
#             {
#               "class": "green color",
# ...

# %%
#read the image
im = Image.open("waterImage02.jpg")

#show image
plt.imshow(im)

# %%
with open('./waterImage03.jpg', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.5',
        classifier_ids='default').get_result()
print(json.dumps(classes, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "person",
#               "score": 0.595
#             },
#             {
#               "class": "arroyo (stream)",
#               "score": 0.57,
#               "type_hierarchy": "/nature/valley/arroyo (stream)"
#             },
#             {
#               "class": "valley",
#               "score": 0.571
#             },
#             {
#               "class": "nature",
#               "score": 0.733
#             },
#             {
#               "class": "riverbed",
#               "score": 0.562,
#               "type_hierarchy": "/nature/riverbed"
#             },
#             {
#               "class": "fieldwork",
#               "score": 0.555,
#               "type_hierarchy": "/defensive structure/fortification/fieldwork"
#             },
#             {
# ...

# %%
#read the image
im = Image.open("waterImage03.jpg")

#show image
plt.imshow(im)
